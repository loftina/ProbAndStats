# %% [markdown]
# # 1

# %%
cs = read.table(file = "/Users/loftina/Downloads/Concr.Strength.1s.Data.txt" ,header=T)

# %%
attach(cs)
hist(Str, freq = F)
lines(density(Str))
stem(Str)
# Out:
#   The decimal point is at the |
#
#   41 | 5
#   42 | 39
#   43 | 1445788
#   44 | 122357
#   45 | 1446
#   46 | 00246
#   47 | 3577
#   48 | 36
#   49 | 3
# Plot with title “Histogram of Str”

# %% [markdown]
# The shape of the stem and leaf plot directly mirrors the histogram if rotated 90 degrees left. The histogram is roughly normal with a slight right skew.

# %% [markdown]
# # 2

# %%
temp = read.table(file = "/Users/loftina/Downloads/Temp.Long.Lat.txt" ,header=T)

# %% [markdown]
# ### (A)

# %%
attach(temp)
pairs(temp[2:4])
# Out:
# The following objects are masked from temp (pos = 4):
#
#     City, JanTemp, Lat, Long
#
# The following objects are masked from temp (pos = 5):
#
#     City, JanTemp, Lat, Long
#
# The following objects are masked from temp (pos = 6):
#
#     City, JanTemp, Lat, Long
# plot without title

# %% [raw]
# Latitude appears to be a much better predictor of a city's temperature. JanTemp has a clearer negative correlation with Latitude while the plot between Temp and Long has much higher variance.

# %% [markdown]
# ### (B)

# %%
library(scatterplot3d)
scatterplot3d(x = Lat, y = Long, z = JanTemp, angle = 45)
# Out:
# plot without title

# %% [markdown]
# Latitude again appears to be the better predictor as the data points group around a downward sloping line. Meanwhile the data appears to be randomly scattered when viewed from the lens of longitude.

# %% [markdown]
# # 3

# %%
data("airquality")
pairs(airquality[1:5])
# Out:
# plot without title

# %% [markdown]
# ### (A)
# Yes, hotter days correlate with higher ozone levels

# %% [markdown]
# ### (B)
# No, higher ozone levels correlate with low wind

# %% [markdown]
# ### (C)
# Ozone levels appear to increase with increased solar radiation

# %% [markdown]
# ### (D)

# %%
out <- split( airquality , f = airquality$Month)
for (df in out){
    boxplot(df[1], ylim = c(0, 200))
}
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# The fourth boxplot for the 8th month. Although the median is lower than the third plot it appears to have a much higher maximum and upper quartile leading to a higher mean.
