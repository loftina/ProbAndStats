# %%
count <- rep(0,100)
for (i in 1:100)
{
    y = sample(c(1,2,3,4,5,6), prob=c(1/6,1/6,1/6,1/6,1/6,1/6), size=100, replace=T)
    z = mean(y)
    
    count[i] <- count[i] + z
}
count
# Out:
#   [1] 3.38 3.62 3.73 3.42 3.45 3.36 3.48 3.61 3.66 3.42 3.56 3.64 3.40 3.79 3.46
#  [16] 3.48 3.82 3.29 3.23 3.44 3.54 3.49 3.58 3.59 3.51 3.57 3.59 3.50 3.50 3.66
#  [31] 3.65 3.44 3.83 3.60 3.35 3.50 3.73 3.69 3.52 3.67 3.39 3.18 3.35 3.50 3.70
#  [46] 3.60 3.69 3.38 3.46 3.53 3.65 3.43 3.59 3.25 3.47 3.44 3.54 3.33 3.45 3.54
#  [61] 3.41 3.54 3.48 3.42 3.36 3.45 3.42 3.47 3.73 3.69 3.69 3.65 3.28 3.64 3.34
#  [76] 4.07 3.48 3.34 3.32 3.55 3.50 3.53 3.37 3.39 3.95 3.53 3.68 3.64 3.48 3.71
#  [91] 3.55 3.57 3.57 3.50 3.84 3.61 3.79 3.31 3.44 3.54

# %%
hist(count)
# Out:
# Plot with title “Histogram of count”

# %%
.1+2*(.15)+3*(.25)+4*(.35)+5*(.1)
# Out:
# [1] 3.05

# %%
11.05-3.05^2
# Out:
# [1] 1.7475
