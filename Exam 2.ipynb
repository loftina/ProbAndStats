# %% [markdown]
# # 5
# ## C
# ### A

# %%
exp(-2.1)
dpois(x = 0, lambda = 2.1)
# Out:
# [1] 0.1224564
# [1] 0.1224564

# %% [markdown]
# ### B

# %%
exp(-2.1)*(1+2.1+2.1^2/2)
sum(dpois(x = 0:2, lambda = 2.1))
# Out:
# [1] 0.6496314
# [1] 0.6496314

# %% [markdown]
# # 6
# ## A

# %%
choose(9,5)/choose(15,5)
# Out:
# [1] 0.04195804

# %%
choose(6,1)*choose(9,4)/choose(15,5)
# Out:
# [1] 0.2517483

# %%
choose(6,2)*choose(9,3)/choose(15,5)
# Out:
# [1] 0.4195804

# %%
choose(6,3)*choose(9,2)/choose(15,5)
# Out:
# [1] 0.2397602

# %%
choose(6,4)*choose(9,1)/choose(15,5)
# Out:
# [1] 0.04495504

# %%
choose(6,5)*choose(9,0)/choose(15,5)
# Out:
# [1] 0.001998002

# %% [markdown]
# ## B

# %%
phyper(q = 4, m = 6, n = 9, k = 5) - phyper(q = 1, m = 6, n = 9, k = 5)
sum(dhyper(x = 2:4, m = 6, n = 9, k = 5))
# Out:
# [1] 0.7042957
# [1] 0.7042957

# %% [markdown]
# # 11
# ## A

# %%
S <- c(1,2,3,4,5,6)
mean <- (1/6)*sum(S)
cat('mean', mean, '\n')
var <- (1/6)*sum((S-3.5)^2)
cat('var', var)
# Out:
# mean 3.5
# var 2.916667

# %% [markdown]
# ## B

# %%
s1 <- sample(x = S, size = 25, replace = T, prob = rep(1/6, 6))
hist(s1)
# Out:
# Plot with title “Histogram of s1”

# %% [markdown]
# ## C

# %%
s2 <- sample(x = S, size = 50, replace = T, prob = rep(1/6, 6))
hist(s2)
# Out:
# Plot with title “Histogram of s2”

# %%
s3 <- sample(x = S, size = 100, replace = T, prob = rep(1/6, 6))
hist(s3)
# Out:
# Plot with title “Histogram of s3”

# %%
s4 <- sample(x = S, size = 500, replace = T, prob = rep(1/6, 6))
hist(s4)
# Out:
# Plot with title “Histogram of s4”

# %%
s5 <- sample(x = S, size = 1000, replace = T, prob = rep(1/6, 6))
hist(s5)
# Out:
# Plot with title “Histogram of s5”

# %% [markdown]
# The larger the sample, the more uniform it appears

# %% [markdown]
# # 12

# %%
x = runif(50)
y = rnorm(50)

# %%
qqnorm(x)
# Out:
# Plot with title “Normal Q-Q Plot”

# %%
qqnorm(y)
# Out:
# Plot with title “Normal Q-Q Plot”

# %% [markdown]
# The second plot appears more normal since it does not flatten out on both tails like the first plot.
