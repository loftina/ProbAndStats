# %%
x <- rep(0, 1000)
for (i in 1:1000){
    y <- rpois(n = 100, lambda = 5)
    x[i] <- mean(y)
}
hist(x)
# Out:
# Plot with title “Histogram of x”

# %%
(3.5-4)/(1.5/sqrt(50))
# Out:
# [1] -2.357023

# %%
(3.8-4)/(1.5/sqrt(50))
# Out:
# [1] -0.942809

# %%
pnorm(3.8, 4, 1.5/sqrt(50)) - pnorm(3.5, 4, 1.5/sqrt(50))
# Out:
# [1] 0.1636782

# %%
sqrt(431*(1/4))
# Out:
# [1] 10.38027

# %%
(229.5-215.5)/10.38
# Out:
# [1] 1.348748

# %%
1-pbinom(229, 431, .5)
# Out:
# [1] 0.08868041

# %%
pnorm(1.35,215.5,10.38, lower.tail = F)
# Out:
# [1] 1

# %%
1-.1/.5^2
# Out:
# [1] 0.6
